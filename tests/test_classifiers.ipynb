# %%
cassava_class_dirs = sorted(os.listdir(os.path.join(
    ROOT_DIR, "data", "processed", "cassava", "train"
)))
cassava_class_dirs
# Out:
# ['Cassava Bacterial Blight (CBB)',
#  'Cassava Brown Streak Disease (CBSD)',
#  'Cassava Green Mottle (CGM)',
#  'Cassava Mosaic Disease (CMD)',
#  'Healthy']

# %%
rice_class_dirs = sorted(os.listdir(os.path.join(
    ROOT_DIR, "data", "processed", "riceleaf", "train"
)))
rice_class_dirs
# Out:
# ['bacterial_leaf_blight',
#  'brown_spot',
#  'healthy',
#  'leaf_blast',
#  'leaf_scald',
#  'narrow_brown_spot']

# %%
pv_class_dirs = sorted(os.listdir(os.path.join(
    ROOT_DIR, "data", "processed", "plantVillage", "train"
)))
pv_class_dirs
# Out:
# ['Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Apple___Cedar_apple_rust',
#  'Apple___healthy',
#  'Blueberry___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Cherry_(including_sour)___healthy',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Corn_(maize)___Common_rust_',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___healthy',
#  'Grape___Black_rot',
#  'Grape___Esca_(Black_Measles)',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Peach___Bacterial_spot',
#  'Peach___healthy',
#  'Pepper,_bell___Bacterial_spot',
#  'Pepper,_bell___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Raspberry___healthy',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Strawberry___Leaf_scorch',
#  'Strawberry___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___healthy']

# %%
for name, path in {
    "species": PATH_SPECIES,
    "cassava": PATH_CASSAVA,
    "rice": PATH_RICE,
    "plantVillage": PATH_PV
}.items():
    state = torch.load(path, map_location="cpu")
    num_classes = state["heads.head.weight"].shape[0]
    print(f"{name} model classes = {num_classes}")
# Out:
# species model classes = 16
# cassava model classes = 5
# rice model classes = 6
# plantVillage model classes = 38

# %%
# ============================================================
# test_classifiers.ipynb  (single-cell version)
#
# Full inference pipeline test for:
#  - YOLO leaf detection
#  - Species ViT classifier (16 classes)
#  - Cassava / Rice / PlantVillage classifiers
#
# Works fully with your local folder layout.
# ============================================================

import os
import torch
import cv2
import torch.nn as nn
from torchvision import transforms, models
from PIL import Image
from ultralytics import YOLO

print("Torch:", torch.__version__)
import torchvision
print("Torchvision:", torchvision.__version__)

# ------------------------------------------------------------
# 1. RESOLVE PROJECT ROOT (notebook-safe)
# ------------------------------------------------------------
CURRENT_DIR = os.getcwd()
ROOT_DIR = os.path.abspath(os.path.join(CURRENT_DIR, ".."))
MODEL_DIR = os.path.join(ROOT_DIR, "models")
TEST_DIR  = os.path.join(ROOT_DIR, "tests", "test_images")

print("ROOT_DIR:", ROOT_DIR)
print("MODEL_DIR:", MODEL_DIR)
print("TEST_DIR:", TEST_DIR)

# ------------------------------------------------------------
# 2. MODEL PATHS
# ------------------------------------------------------------
PATH_SPECIES = os.path.join(MODEL_DIR, "species_classifier_vit.pth")
PATH_CASSAVA = os.path.join(MODEL_DIR, "cassava_best.pth")
PATH_RICE    = os.path.join(MODEL_DIR, "rice_leaf_best.pth")
PATH_PV      = os.path.join(MODEL_DIR, "plant_village_best.pth")
PATH_YOLO    = os.path.join(MODEL_DIR, "yolo_plantdoc_detect.pt")

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

# ------------------------------------------------------------
# 3. LOAD YOLO MODEL
# ------------------------------------------------------------
yolo = YOLO(PATH_YOLO)

# ------------------------------------------------------------
# 4. IMAGE TRANSFORMS FOR ViT
# ------------------------------------------------------------
IMG_SIZE = 224
vit_tfms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
])

# ------------------------------------------------------------
# 5. LOAD ViT MODELS WITH AUTOMATIC CLASS SIZE DETECTION
# ------------------------------------------------------------
def load_vit(path):
    state = torch.load(path, map_location=device)
    num_classes = state["heads.head.weight"].shape[0]
    
    model = models.vit_b_16(weights=None)
    in_features = model.heads[-1].in_features
    model.heads[-1] = nn.Linear(in_features, num_classes)
    
    model.load_state_dict(state)
    model.to(device)
    model.eval()
    return model

species_model = load_vit(PATH_SPECIES)
cassava_model = load_vit(PATH_CASSAVA)
rice_model    = load_vit(PATH_RICE)
pv_model      = load_vit(PATH_PV)

print("Models loaded.")

# ------------------------------------------------------------
# 6. LOAD LABELS FROM FOLDER NAMES
# ------------------------------------------------------------
def load_class_names(path):
    return sorted([
        d for d in os.listdir(path)
        if os.path.isdir(os.path.join(path, d))
    ])

# species (manual list from your Drive screenshot)
species_labels = [
    "Apple",
    "Blueberry",
    "Cassava",
    "Cherry_(including_sour)",
    "Corn_(maize)",
    "Grape",
    "Orange",
    "Peach",
    "Pepper,_bell",
    "Potato",
    "Raspberry",
    "Rice",
    "Soybean",
    "Squash",
    "Strawberry",
    "Tomato"
]

# cassava = 5 classes
cassava_labels = load_class_names(os.path.join(ROOT_DIR, "data", "processed", "cassava", "train"))

# rice = 6 classes
rice_labels = load_class_names(os.path.join(ROOT_DIR, "data", "processed", "riceleaf", "train"))

# PlantVillage = 38 classes
pv_labels = load_class_names(os.path.join(ROOT_DIR, "data", "processed", "plantVillage", "train"))

print("Species labels:", len(species_labels))
print("Cassava labels:", len(cassava_labels))
print("Rice labels:", len(rice_labels))
print("PlantVillage labels:", len(pv_labels))

# ------------------------------------------------------------
# 7. HELPERS
# ------------------------------------------------------------
def predict_vit(pil_img, model, labels):
    tensor = vit_tfms(pil_img).unsqueeze(0).to(device)
    with torch.no_grad():
        pred = model(tensor).argmax(1).item()
    return labels[pred]

def crop_leaf_from_yolo(image_path):
    results = yolo(image_path)[0]
    if len(results.boxes) == 0:
        print("⚠️ No leaf detected:", os.path.basename(image_path))
        return None
    x1, y1, x2, y2 = results.boxes[0].xyxy[0].cpu().numpy().astype(int)
    img = cv2.imread(image_path)
    crop = img[y1:y2, x1:x2]
    crop = cv2.cvtColor(crop, cv2.COLOR_BGR2RGB)
    return Image.fromarray(crop)

# ------------------------------------------------------------
# 8. RUN TESTS
# ------------------------------------------------------------
def run_tests():
    files = [x for x in os.listdir(TEST_DIR) if x.lower().endswith((".jpg", ".jpeg", ".png"))]
    if not files:
        print("❌ No test images found.")
        return
    
    print("\n========== RUNNING TESTS ==========\n")
    results = []
    
    for f in files:
        path = os.path.join(TEST_DIR, f)
        print(f"\n🟦 Testing: {f}")

        leaf = crop_leaf_from_yolo(path)
        if leaf is None:
            continue

        species = predict_vit(leaf, species_model, species_labels)
        print("  🔍 Species:", species)

        if species == "Cassava":
            disease = predict_vit(leaf, cassava_model, cassava_labels)
        elif species == "Rice":
            disease = predict_vit(leaf, rice_model, rice_labels)
        else:
            disease = predict_vit(leaf, pv_model, pv_labels)

        print("  🦠 Disease:", disease)
        results.append((f, species, disease))
    
    print("\n========== RESULTS ==========\n")
    for f, s, d in results:
        print(f"{f:25s} | {s:12s} | {d}")

    return results

# ------------------------------------------------------------
# RUN
# ------------------------------------------------------------
run_tests()
# Out:
# Torch: 2.3.0+cpu
# Torchvision: 0.18.0+cpu
# ROOT_DIR: c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection
# MODEL_DIR: c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\models
# TEST_DIR: c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images
# Using device: cpu
# Models loaded.
# Species labels: 16
# Cassava labels: 5
# Rice labels: 6
# PlantVillage labels: 38
#
# ========== RUNNING TESTS ==========
#
#
# 🟦 Testing: cassava_Cassava Bacterial Blight (CBB)_3944841972.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Cassava Bacterial Blight (CBB)_3944841972.jpg: 480x640 9 leafs, 185.7ms
# Speed: 3.7ms preprocess, 185.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Cassava Bacterial Blight (CBB)
#
# 🟦 Testing: cassava_Cassava Bacterial Blight (CBB)_586054705.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Cassava Bacterial Blight (CBB)_586054705.jpg: 480x640 9 leafs, 195.5ms
# Speed: 3.1ms preprocess, 195.5ms inference, 16.8ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Healthy
#
# 🟦 Testing: cassava_Cassava Brown Streak Disease (CBSD)_4219389723.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Cassava Brown Streak Disease (CBSD)_4219389723.jpg: 480x640 5 leafs, 188.9ms
# Speed: 3.2ms preprocess, 188.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Tomato___Late_blight
#
# 🟦 Testing: cassava_Cassava Brown Streak Disease (CBSD)_486370102.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Cassava Brown Streak Disease (CBSD)_486370102.jpg: 480x640 4 leafs, 175.3ms
# Speed: 3.1ms preprocess, 175.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Cassava Brown Streak Disease (CBSD)
#
# 🟦 Testing: cassava_Cassava Green Mottle (CGM)_3311389928.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Cassava Green Mottle (CGM)_3311389928.jpg: 480x640 10 leafs, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Cassava Brown Streak Disease (CBSD)
#
# 🟦 Testing: cassava_Cassava Green Mottle (CGM)_4183847559.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Cassava Green Mottle (CGM)_4183847559.jpg: 480x640 8 leafs, 175.2ms
# Speed: 3.0ms preprocess, 175.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Cassava Green Mottle (CGM)
#
# 🟦 Testing: cassava_Cassava Mosaic Disease (CMD)_4084470563.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Cassava Mosaic Disease (CMD)_4084470563.jpg: 480x640 20 leafs, 183.4ms
# Speed: 3.2ms preprocess, 183.4ms inference, 16.9ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Healthy
#
# 🟦 Testing: cassava_Cassava Mosaic Disease (CMD)_719222576.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Cassava Mosaic Disease (CMD)_719222576.jpg: 480x640 3 leafs, 177.1ms
# Speed: 2.9ms preprocess, 177.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Cassava Mosaic Disease (CMD)
#
# 🟦 Testing: cassava_Healthy_1272381477.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Healthy_1272381477.jpg: 480x640 10 leafs, 175.8ms
# Speed: 2.9ms preprocess, 175.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Cassava Bacterial Blight (CBB)
#
# 🟦 Testing: cassava_Healthy_1763396057.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\cassava_Healthy_1763396057.jpg: 480x640 10 leafs, 217.6ms
# Speed: 2.9ms preprocess, 217.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Healthy
#
# 🟦 Testing: PlantDoc_07c.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\PlantDoc_07c.jpg: 416x640 1 leaf, 190.4ms
# Speed: 2.8ms preprocess, 190.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Cassava Green Mottle (CGM)
#
# 🟦 Testing: PlantDoc_1355.50commonrust.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\PlantDoc_1355.50commonrust.jpg: 640x448 1 leaf, 285.0ms
# Speed: 4.0ms preprocess, 285.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 448)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
#
# 🟦 Testing: PlantDoc_4825902504_5fa80b65b8_z.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\PlantDoc_4825902504_5fa80b65b8_z.jpg: 448x640 1 leaf, 261.9ms
# Speed: 3.2ms preprocess, 261.9ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#   🔍 Species: Orange
#   🦠 Disease: Tomato___Late_blight
#
# 🟦 Testing: PlantDoc_IMG_42231.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\PlantDoc_IMG_42231.jpg: 480x640 1 leaf, 216.6ms
# Speed: 4.0ms preprocess, 216.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___healthy
#
# 🟦 Testing: PlantDoc_powdery-mildew-on-pumpkin-leaves-close-up-2.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\PlantDoc_powdery-mildew-on-pumpkin-leaves-close-up-2.jpg: 480x640 2 leafs, 248.9ms
# Speed: 4.0ms preprocess, 248.9ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Cassava
#   🦠 Disease: Cassava Brown Streak Disease (CBSD)
#
# 🟦 Testing: PlantDoc_tomato_virus_04_zoom.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\PlantDoc_tomato_virus_04_zoom.jpg: 480x640 4 leafs, 244.8ms
# Speed: 4.9ms preprocess, 244.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Tomato___Late_blight
#
# 🟦 Testing: plantVillage_Apple___Apple_scab_14c623e5-051c-42f6-9e4f-f7a93e6a723c___FREC_Scab 2965.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Apple___Apple_scab_14c623e5-051c-42f6-9e4f-f7a93e6a723c___FREC_Scab 2965.JPG: 640x640 3 leafs, 329.4ms
# Speed: 7.4ms preprocess, 329.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Apple
#   🦠 Disease: Apple___Apple_scab
#
# 🟦 Testing: plantVillage_Apple___Apple_scab_716a13b6-1747-40d8-96d7-5ec1c183b3b5___FREC_Scab 3004.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Apple___Apple_scab_716a13b6-1747-40d8-96d7-5ec1c183b3b5___FREC_Scab 3004.JPG: 640x640 2 leafs, 330.9ms
# Speed: 8.0ms preprocess, 330.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Apple
#   🦠 Disease: Apple___Apple_scab
#
# 🟦 Testing: plantVillage_Apple___Black_rot_47800fc6-b681-46ab-aec3-01076d650c5d___JR_FrgE.S 3051.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Apple___Black_rot_47800fc6-b681-46ab-aec3-01076d650c5d___JR_FrgE.S 3051.JPG: 640x640 1 leaf, 320.3ms
# Speed: 7.4ms preprocess, 320.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Apple
#   🦠 Disease: Apple___Black_rot
#
# 🟦 Testing: plantVillage_Apple___Black_rot_74dfd7d6-e78e-47d9-8530-35acab5cd01f___JR_FrgE.S 3027.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Apple___Black_rot_74dfd7d6-e78e-47d9-8530-35acab5cd01f___JR_FrgE.S 3027.JPG: 640x640 1 leaf, 386.8ms
# Speed: 7.3ms preprocess, 386.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Apple
#   🦠 Disease: Apple___Black_rot
#
# 🟦 Testing: plantVillage_Apple___Cedar_apple_rust_56cc0223-46b0-44d3-ba43-66d3def44f1d___FREC_C.Rust 3834.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Apple___Cedar_apple_rust_56cc0223-46b0-44d3-ba43-66d3def44f1d___FREC_C.Rust 3834.JPG: 640x640 1 leaf, 362.0ms
# Speed: 8.4ms preprocess, 362.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Apple
#   🦠 Disease: Apple___Cedar_apple_rust
#
# 🟦 Testing: plantVillage_Apple___Cedar_apple_rust_85eb91f6-f8f0-438e-afbc-ca12551ee404___FREC_C.Rust 9884.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Apple___Cedar_apple_rust_85eb91f6-f8f0-438e-afbc-ca12551ee404___FREC_C.Rust 9884.JPG: 640x640 2 leafs, 307.1ms
# Speed: 7.9ms preprocess, 307.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Apple___Cedar_apple_rust
#
# 🟦 Testing: plantVillage_Apple___healthy_63f2f961-ac3f-4a2d-9fc1-6987e8da97cc___RS_HL 7447.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Apple
6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Cherry_(including_sour)
#   🦠 Disease: Cherry_(including_sour)___Powdery_mildew
#
# 🟦 Testing: plantVillage_Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot_9c78e47a-8ed7-4b8f-8230-499e2d135a0a___RS_GLSp 4335.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot_9c78e47a-8ed7-4b8f-8230-499e2d135a0a___RS_GLSp 4335.JPG: 640x640 1 leaf, 328.4ms
# Speed: 8.1ms preprocess, 328.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
#
# 🟦 Testing: plantVillage_Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot_a7dc9342-e554-4245-98f7-d35a3cbd52fe___RS_GLSp 7281.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot_a7dc9342-e554-4245-98f7-d35a3cbd52fe___RS_GLSp 7281.JPG: 640x640 2 leafs, 302.8ms
# Speed: 7.8ms preprocess, 302.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
#
# 🟦 Testing: plantVillage_Corn_(maize)___Common_rust__RS_Rust 1896.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Corn_(maize)___Common_rust__RS_Rust 1896.JPG: 640x640 1 leaf, 304.7ms
# Speed: 7.3ms preprocess, 304.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___Common_rust_
#
# 🟦 Testing: plantVillage_Corn_(maize)___Common_rust__RS_Rust 1970.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Corn_(maize)___Common_rust__RS_Rust 1970.JPG: 640x640 1 leaf, 307.8ms
# Speed: 7.4ms preprocess, 307.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___Common_rust_
#
# 🟦 Testing: plantVillage_Corn_(maize)___healthy_c9a59c8c-b828-4a5c-a3d3-ecf4833a02d2___R.S_HL 5494 copy.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Corn_(maize)___healthy_c9a59c8c-b828-4a5c-a3d3-ecf4833a02d2___R.S_HL 5494 copy.jpg: 640x640 3 leafs, 318.5ms
# Speed: 7.5ms preprocess, 318.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___healthy
#
# 🟦 Testing: plantVillage_Corn_(maize)___healthy_fa7d8ffc-4e21-4a6d-9042-63fa7e4a1df0___R.S_HL 0636 copy 3.jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Corn_(maize)___healthy_fa7d8ffc-4e21-4a6d-9042-63fa7e4a1df0___R.S_HL 0636 copy 3.jpg: 640x640 1 leaf, 303.9ms
# Speed: 7.7ms preprocess, 303.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___healthy
#
# 🟦 Testing: plantVillage_Corn_(maize)___Northern_Leaf_Blight_2bad1ec2-1bd5-431c-919d-31247d9f32e2___RS_NLB 4180.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Corn_(maize)___Northern_Leaf_Blight_2bad1ec2-1bd5-431c-919d-31247d9f32e2___RS_NLB 4180.JPG: 640x640 2 leafs, 314.8ms
# Speed: 8.2ms preprocess, 314.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___Northern_Leaf_Blight
#
# 🟦 Testing: plantVillage_Corn_(maize)___Northern_Leaf_Blight_739f7cf2-2f79-473b-864f-1a35916dc5a7___RS_NLB 4094.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Corn_(maize)___Northern_Leaf_Blight_739f7cf2-2f79-473b-864f-1a35916dc5a7___RS_NLB 4094.JPG: 640x640 1 leaf, 306.1ms
# Speed: 7.9ms preprocess, 306.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Corn_(maize)
#   🦠 Disease: Corn_(maize)___Northern_Leaf_Blight
#
# 🟦 Testing: plantVillage_Grape___Black_rot_5c237a28-eeef-4cc6-a6c5-f9360022dd3e___FAM_B.Rot 5081.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Grape___Black_rot_5c237a28-eeef-4cc6-a6c5-f9360022dd3e___FAM_B.Rot 5081.JPG: 640x640 6 leafs, 322.0ms
# Speed: 7.3ms preprocess, 322.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species:
a98961-90fb-4ff5-a6db-6313fa61f74b___PSU_CG 2125.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Tomato___Tomato_mosaic_virus_22a98961-90fb-4ff5-a6db-6313fa61f74b___PSU_CG 2125.JPG: 640x640 4 leafs, 347.6ms
# Speed: 9.0ms preprocess, 347.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Tomato
#   🦠 Disease: Tomato___Tomato_mosaic_virus
#
# 🟦 Testing: plantVillage_Tomato___Tomato_mosaic_virus_fb199918-5c7f-4285-993b-3ed212140456___PSU_CG 2124.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Tomato___Tomato_mosaic_virus_fb199918-5c7f-4285-993b-3ed212140456___PSU_CG 2124.JPG: 640x640 2 leafs, 318.0ms
# Speed: 10.4ms preprocess, 318.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Tomato
#   🦠 Disease: Tomato___Tomato_mosaic_virus
#
# 🟦 Testing: plantVillage_Tomato___Tomato_Yellow_Leaf_Curl_Virus_a408024e-b016-4351-b4ea-54ee065eec85___UF.GRC_YLCV_Lab 03039.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Tomato___Tomato_Yellow_Leaf_Curl_Virus_a408024e-b016-4351-b4ea-54ee065eec85___UF.GRC_YLCV_Lab 03039.JPG: 640x640 2 leafs, 345.8ms
# Speed: 8.0ms preprocess, 345.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Tomato
#   🦠 Disease: Tomato___Tomato_Yellow_Leaf_Curl_Virus
#
# 🟦 Testing: plantVillage_Tomato___Tomato_Yellow_Leaf_Curl_Virus_d744882b-02ac-4904-8e96-4920b39ad5ce___YLCV_GCREC 5246.JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\plantVillage_Tomato___Tomato_Yellow_Leaf_Curl_Virus_d744882b-02ac-4904-8e96-4920b39ad5ce___YLCV_GCREC 5246.JPG: 640x640 2 leafs, 412.4ms
# Speed: 9.6ms preprocess, 412.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Tomato
#   🦠 Disease: Tomato___Tomato_Yellow_Leaf_Curl_Virus
#
# 🟦 Testing: riceleaf_bacterial_leaf_blight_bacterial_leaf_blight (118).JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_bacterial_leaf_blight_bacterial_leaf_blight (118).JPG: 640x640 2 leafs, 296.9ms
# Speed: 10.7ms preprocess, 296.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Rice
#   🦠 Disease: bacterial_leaf_blight
#
# 🟦 Testing: riceleaf_bacterial_leaf_blight_bacterial_leaf_blight (316).JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_bacterial_leaf_blight_bacterial_leaf_blight (316).JPG: 640x640 2 leafs, 364.0ms
# Speed: 11.1ms preprocess, 364.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Rice
#   🦠 Disease: bacterial_leaf_blight
#
# 🟦 Testing: riceleaf_brown_spot_brown_spot (210).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_brown_spot_brown_spot (210).jpg: 640x640 2 leafs, 308.0ms
# Speed: 11.5ms preprocess, 308.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Rice
#   🦠 Disease: brown_spot
#
# 🟦 Testing: riceleaf_brown_spot_brown_spot (346).JPG
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_brown_spot_brown_spot (346).JPG: 640x640 (no detections), 332.7ms
# Speed: 11.4ms preprocess, 332.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ No leaf detected: riceleaf_brown_spot_brown_spot (346).JPG
#
# 🟦 Testing: riceleaf_healthy_healthy (271).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_healthy_healthy (271).jpg: 640x640 1 leaf, 285.3ms
# Speed: 11.6ms preprocess, 285.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Rice
#   🦠 Disease: healthy
#
# 🟦 Testing: riceleaf_healthy_healthy (325).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_healthy_healthy (325).jpg: 640x640 1 leaf, 339.8ms
# Speed: 10.9ms preprocess, 339.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#   🔍 Species: Rice
#   🦠 Disease: healthy
#
# 🟦 Testing: riceleaf_leaf_blast_leaf_blast (212).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_leaf_blast_leaf_blast (212).jpg: 640x640 (no detections), 306.1ms
# Speed: 11.1ms preprocess, 306.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ No leaf detected: riceleaf_leaf_blast_leaf_blast (212).jpg
#
# 🟦 Testing: riceleaf_leaf_blast_leaf_blast (243).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_leaf_blast_leaf_blast (243).jpg: 640x640 (no detections), 286.3ms
# Speed: 7.2ms preprocess, 286.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ No leaf detected: riceleaf_leaf_blast_leaf_blast (243).jpg
#
# 🟦 Testing: riceleaf_leaf_scald_leaf_scald (157).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_leaf_scald_leaf_scald (157).jpg: 640x640 (no detections), 284.6ms
# Speed: 11.7ms preprocess, 284.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ No leaf detected: riceleaf_leaf_scald_leaf_scald (157).jpg
#
# 🟦 Testing: riceleaf_leaf_scald_leaf_scald (226).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_leaf_scald_leaf_scald (226).jpg: 640x640 (no detections), 299.6ms
# Speed: 11.4ms preprocess, 299.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ No leaf detected: riceleaf_leaf_scald_leaf_scald (226).jpg
#
# 🟦 Testing: riceleaf_narrow_brown_spot_narrow_brown (109).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_narrow_brown_spot_narrow_brown (109).jpg: 640x640 (no detections), 307.5ms
# Speed: 10.7ms preprocess, 307.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ No leaf detected: riceleaf_narrow_brown_spot_narrow_brown (109).jpg
#
# 🟦 Testing: riceleaf_narrow_brown_spot_narrow_brown (273).jpg
#
# image 1/1 c:\Users\User\Desktop\Data Science\Projects\crop-disease-detection\tests\test_images\riceleaf_narrow_brown_spot_narrow_brown (273).jpg: 640x640 (no detections), 301.6ms
# Speed: 10.9ms preprocess, 301.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ No leaf detected: riceleaf_narrow_brown_spot_narrow_brown (273).jpg
#
# ========== RESULTS ==========
#
# ...
# plantVillage_Tomato___Early_blight_4deeae7f-b339-4d5b-969c-b69ea27c1636___RS_Erly.B 7736.JPG | Tomato       | Tomato___Early_blight
# plantVillage_Tomato___Early_blight_bac9d43f-fc43-4b89-bc2a-b8ba4a040059___RS_Erly.B 7724.JPG | Tomato       | Tomato___Early_blight
# plantVillage_Tomato___healthy_18fa622c-8257-479a-9c81-7a6fe9a3a41b___GH_HL Leaf 428.JPG | Tomato       | Tomato___Late_blight
# plantVillage_Tomato___healthy_d676d2f7-13a7-4d79-91fc-757b5d0bde6f___RS_HL 0601.JPG | Tomato       | Tomato___healthy
# plantVillage_Tomato___Late_blight_01c391d2-1b3a-4b58-b205-a75674bba6e9___GHLB2 Leaf 8824.JPG | Tomato       | Tomato___Late_blight
# plantVillage_Tomato___Late_blight_a7049041-4ef3-4c55-b4bf-7721ca5630f4___RS_Late.B 5142.JPG | Tomato       | Tomato___Late_blight
# plantVillage_Tomato___Leaf_Mold_0c0debed-e807-4236-a2e3-d9b72f54367f___Crnl_L.Mold 6899.JPG | Tomato       | Tomato___Leaf_Mold
# plantVillage_Tomato___Leaf_Mold_9dd60be7-b16d-493d-acdf-f5b7446754c7___Crnl_L.Mold 8782.JPG | Tomato       | Tomato___Leaf_Mold
# plantVillage_Tomato___Septoria_leaf_spot_694af91d-fa2c-4bdd-a1b4-0ebacc3a2cca___Matt.S_CG 1588.JPG | Tomato       | Tomato___Early_blight
# plantVillage_Tomato___Septoria_leaf_spot_6bda66a5-562c-4ad9-9e14-7d76dcbd4eef___Keller.St_CG 1880.JPG | Tomato       | Tomato___Septoria_leaf_spot
# plantVillage_Tomato___Spider_mites Two-spotted_spider_mite_83d3d054-0ca6-41bd-9b65-ae5d27f9605d___Com.G_SpM_FL 1384.JPG | Tomato       | Tomato___Spider_mites Two-spotted_spider_mite
# plantVillage_Tomato___Spider_mites Two-spotted_spider_mite_88ce9b84-50b8-4ffa-8628-1d5fe9e9a94e___Com.G_SpM_FL 1547.JPG | Tomato       | Tomato___Spider_mites Two-spotted_spider_mite
# plantVillage_Tomato___Target_Spot_4a24322a-bd1c-493c-9da4-536b89eeaf2e___Com.G_TgS_FL 8000.JPG | Tomato       | Tomato___Target_Spot
# plantVillage_Tomato___Target_Spot_a22c1ee8-6ad5-44e3-adb4-2e0223b3fa2b___Com.G_TgS_FL 0981.JPG | Tomato       | Tomato___Target_Spot
# plantVillage_Tomato___Tomato_mosaic_virus_22a98961-90fb-4ff5-a6db-6313fa61f74b___PSU_CG 2125.JPG | Tomato       | Tomato___Tomato_mosaic_virus
# plantVillage_Tomato___Tomato_mosaic_virus_fb199918-5c7f-4285-993b-3ed212140456___PSU_CG 2124.JPG | Tomato       | Tomato___Tomato_mosaic_virus
# plantVillage_Tomato___Tomato_Yellow_Leaf_Curl_Virus_a408024e-b016-4351-b4ea-54ee065eec85___UF.GRC_YLCV_Lab 03039.JPG | Tomato       | Tomato___Tomato_Yellow_Leaf_Curl_Virus
# plantVillage_Tomato___Tomato_Yellow_Leaf_Curl_Virus_d744882b-02ac-4904-8e96-4920b39ad5ce___YLCV_GCREC 5246.JPG | Tomato       | Tomato___Tomato_Yellow_Leaf_Curl_Virus
# riceleaf_bacterial_leaf_blight_bacterial_leaf_blight (118).JPG | Rice         | bacterial_leaf_blight
# riceleaf_bacterial_leaf_blight_bacterial_leaf_blight (316).JPG | Rice         | bacterial_leaf_blight
# riceleaf_brown_spot_brown_spot (210).jpg | Rice         | brown_spot
# riceleaf_healthy_healthy (271).jpg | Rice         | healthy
# riceleaf_healthy_healthy (325).jpg | Rice         | healthy
# [('cassava_Cassava Bacterial Blight (CBB)_3944841972.jpg',
#   'Cassava',
#   'Cassava Bacterial Blight (CBB)'),
#  ('cassava_Cassava Bacterial Blight (CBB)_586054705.jpg',
#   'Cassava',
#   'Healthy'),
#  ('cassava_Cassava Brown Streak Disease (CBSD)_4219389723.jpg',
#   'Corn_(maize)',
#   'Tomato___Late_blight'),
#  ('cassava_Cassava Brown Streak Disease (CBSD)_486370102.jpg',
#   'Cassava',
#   'Cassava Brown Streak Disease (CBSD)'),
#  ('cassava_Cassava Green Mottle (CGM)_3311389928.jpg',
#   'Cassava',
#   'Cassava Brown Streak Disease (CBSD)'),
#  ('cassava_Cassava Green Mottle (CGM)_4183847559.jpg',
#   'Cassava',
#   'Cassava Green Mottle (CGM)'),
#  ('cassava_Cassava Mosaic Disease (CMD)_4084470563.jpg', 'Cassava', 'Healthy'),
#  ('cassava_Cassava Mosaic Disease (CMD)_719222576.jpg',
#   'Cassava',
#   'Cassava Mosaic Disease (CMD)'),
#  ('cassava_Healthy_1272381477.jpg',
#   'Cassava',
#   'Cassava Bacterial Blight (CBB)'),
#  ('cassava_Healthy_1763396057.jpg', 'Cassava', 'Healthy'),
#  ('PlantDoc_07c.jpg', 'Cassava', 'Cassava Green Mottle (CGM)'),
#  ('PlantDoc_1355.50commonrust.jpg',
#   'Corn_(maize)',
#   'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot'),
#  ('PlantDoc_4825902504_5fa80b65b8_z.jpg', 'Orange', 'Tomato___Late_blight'),
#  ('PlantDoc_IMG_42231.jpg', 'Corn_(maize)', 'Corn_(maize)___healthy'),
#  ('PlantDoc_powdery-mildew-on-pumpkin-leaves-close-up-2.jpg',
#   'Cassava',
#   'Cassava Brown Streak Disease (CBSD)'),
#  ('PlantDoc_tomato_virus_04_zoom.jpg', 'Corn_(maize)', 'Tomato___Late_blight'),
#  ('plantVillage_Apple___Apple_scab_14c623e5-051c-42f6-9e4f-f7a93e6a723c___FREC_Scab 2965.JPG',
#   'Apple',
#   'Apple___Apple_scab'),
#  ('plantVillage_Apple___Apple_scab_716a13b6-1747-40d8-96d7-5ec1c183b3b5___FREC_Scab 3004.JPG',
#   'Apple',
#   'Apple___Apple_scab'),
#  ('plantVillage_Apple___Black_rot_47800fc6-b681-46ab-aec3-01076d650c5d___JR_FrgE.S 3051.JPG',
#   'Apple',
#   'Apple___Black_rot'),
#  ('plantVillage_Apple___Black_rot_74dfd7d6-e78e-47d9-8530-35acab5cd01f___JR_FrgE.S 3027.JPG',
#   'Apple',
#   'Apple___Black_rot'),
#  ('plantVillage_Apple___Cedar_apple_rust_56cc0223-46b0-44d3-ba43-66d3def44f1d___FREC_C.Rust 3834.JPG',
#   'Apple',
#   'Apple___Cedar_apple_rust'),
#  ('plantVillage_Apple___Cedar_apple_rust_85eb91f6-f8f0-438e-afbc-ca12551ee404___FREC_C.Rust 9884.JPG',
#   'Corn_(maize)',
#   'Apple___Cedar_apple_rust'),
#  ('plantVillage_Apple___healthy_63f2f961-ac3f-4a2d-9fc1-6987e8da97cc___RS_HL 7447.JPG',
#   'Apple',
#   'Apple___healthy'),
#  ('plantVillage_Apple___healthy_95e92b80-49d6-4589-95ad-be379775d193___RS_HL 7451.JPG',
#   'Apple',
#   'Apple___healthy'),
#  ('plantVillage_Blueberry___healthy_6533061f-86a1-4632-9f84-7c97f0163e26___RS_HL 0527.JPG',
#   'Blueberry',
#   'Blueberry___healthy'),
#  ('plantVillage_Blueberry___healthy_7d2ee2cd-b47c-4b02-b5a0-96b637a39d7a___RS_HL 5354.JPG',
#   'Blueberry',
#   'Blueberry___healthy'),
#  ('plantVillage_Cherry_(including_sour)___healthy_90f22e39-5ee0-4973-ae80-ef987d05990a___JR_HL 4085.JPG',
#   'Cherry_(including_sour)',
#   'Cherry_(including_sour)___healthy'),
#  ('plantVillage_Cherry_(including_sour)___healthy_9705f45b-e0e3-4d0e-a0f0-ad1c9b3b32a0___JR_HL 4311.JPG',
#   'Cherry_(including_sour)',
#   'Cherry_(including_sour)___healthy'),
#  ('plantVillage_Cherry_(including_sour)___Powdery_mildew_5bd34c12-bc95-4068-bac8-b6ca8f45d6ae___FREC_Pwd.M 4950.JPG',
#   'Cherry_(including_sour)',
#   'Cherry_(including_sour)___Powdery_mildew'),
#  ('plantVillage_Cherry_(including_sour)___Powdery_mildew_e7fe2094-95a1-40fe-ba1d-687ab0756edb___FREC_Pwd.M 0541.JPG',
#   'Cherry_(including_sour)',
#   'Cherry_(including_sour)___Powdery_mildew'),
#  ('plantVillage_Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot_9c78e47a-8ed7-4b8f-8230-499e2d135a0a___RS_GLSp 4335.JPG',
#   'Corn_(maize)',
#   'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot'),
#  ('plantVillage_Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot_a7dc9342-e554-4245-98f7-d35a3cbd52fe___RS_GLSp 7281.JPG',
#   'Corn_(maize)',
#   'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot'),
#  ('plantVillage_Corn_(maize)___Common_rust__RS_Rust 1896.JPG',
#   'Corn_(maize)',
#   'Corn_(maize)___Common_rust_'),
#  ('plantVillage_Corn_(maize)___Common_rust__RS_Rust 1970.JPG',
#   'Corn_(maize)',
#   'Corn_(maize)___Common_rust_'),
#  ('plantVillage_Corn_(maize)___healthy_c9a59c8c-b828-4a5c-a3d3-ecf4833a02d2___R.S_HL 5494 copy.jpg',
#   'Corn_(maize)',
#   'Corn_(maize)___healthy'),
#  ('plantVillage_Corn_(maize)___healthy_fa7d8ffc-4e21-4a6d-9042-63fa7e4a1df0___R.S_HL 0636 copy 3.jpg',
#   'Corn_(maize)',
#   'Corn_(maize)___healthy'),
#  ('plantVillage_Corn_(maize)___Northern_Leaf_Blight_2bad1ec2-1bd5-431c-919d-31247d9f32e2___RS_NLB 4180.JPG',
#   'Corn_(maize)',
#   'Corn_(maize)___Northern_Leaf_Blight'),
#  ('plantVillage_Corn_(maize)___Northern_Leaf_Blight_739f7cf2-2f79-473b-864f-1a35916dc5a7___RS_NLB 4094.JPG',
#   'Corn_(maize)',
#   'Corn_(maize)___Northern_Leaf_Blight'),
#  ('plantVillage_Grape___Black_rot_5c237a28-eeef-4cc6-a6c5-f9360022dd3e___FAM_B.Rot 5081.JPG',
#   'Strawberry',
#   'Strawberry___Leaf_scorch'),
#  ('plantVillage_Grape___Black_rot_73e582d5-9e4d-4208-a206-c85050968f6f___FAM_B.Rot 5083.JPG',
#   'Grape',
#   'Grape___Black_rot'),
#  ('plantVillage_Grape___Esca_(Black_Measles)_8c02d3db-062d-433e-b76c-b1ab7d92f6a9___FAM_B.Msls 4360.JPG',
#   'Grape',
#   'Grape___Esca_(Black_Measles)'),
#  ('plantVillage_Grape___Esca_(Black_Measles)_f05eb083-7d59-40e6-9426-f06d428e81ab___FAM_B.Msls 1832.JPG',
#   'Grape',
#   'Grape___Esca_(Black_Measles)'),
#  ('plantVillage_Grape___healthy_603a6e76-4457-4ac2-a549-1560c7c1cf30___Mt.N.V_HL 9065.JPG',
#   'Grape',
#   'Grape___healthy'),
#  ('plantVillage_Grape___healthy_6b11a8e2-a729-4f80-9836-e90402c0b47f___Mt.N.V_HL 6062.JPG',
#   'Grape',
#   'Grape___healthy'),
#  ('plantVillage_Grape___Leaf_blight_(Isariopsis_Leaf_Spot)_66f9ad0a-c645-4cf0-b0a8-bf798dc4b918___FAM_L.Blight 1588.JPG',
#   'Grape',
#   'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)'),
#  ('plantVillage_Grape___Leaf_blight_(Isariopsis_Leaf_Spot)_eb4675db-7042-4d07-b732-0b9b8ca79fe6___FAM_L.Blight 1668.JPG',
#   'Grape',
#   'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)'),
#  ('plantVillage_Orange___Haunglongbing_(Citrus_greening)_14e1124a-e76b-4f28-b691-670db8ce0a8e___CREC_HLB 5602.JPG',
#   'Orange',
#   'Orange___Haunglongbing_(Citrus_greening)'),
#  ('plantVillage_Orange___Haunglongbing_(Citrus_greening)_82055f8c-531b-4c89-b191-960cb07f75cf___CREC_HLB 6556.JPG',
#   'Orange',
#   'Orange___Haunglongbing_(Citrus_greening)'),
#  ('plantVillage_Peach___Bacterial_spot_1adc12f3-507f-45ca-9966-9b2bd9bc03e6___Rut._Bact.S 1265.JPG',
#   'Peach',
#   'Peach___Bacterial_spot'),
#  ('plantVillage_Peach___Bacterial_spot_bc69656f-9dae-4e3a-bd39-04c504cca208___Rut._Bact.S 0895.JPG',
#   'Peach',
#   'Peach___Bacterial_spot'),
#  ('plantVillage_Peach___healthy_0ccb71ac-bf4e-4722-a545-d70f47ec4591___Rutg._HL 3533.JPG',
#   'Peach',
#   'Peach___healthy'),
#  ('plantVillage_Peach___healthy_f28221b4-5659-4391-ae23-25cb20d3176d___Rutg._HL 3641.JPG',
#   'Peach',
#   'Peach___healthy'),
#  ('plantVillage_Pepper,_bell___Bacterial_spot_1732db7e-9901-46df-b20e-3ca49ff1dbad___NREC_B.Spot 1791.JPG',
#   'Pepper,_bell',
#   'Pepper,_bell___Bacterial_spot'),
#  ('plantVillage_Pepper,_bell___Bacterial_spot_a3f51b14-cfbc-4e34-bca0-2ff18996184d___JR_B.Spot 8841.JPG',
#   'Pepper,_bell',
#   'Pepper,_bell___Bacterial_spot'),
#  ('plantVillage_Pepper,_bell___healthy_5d5bbf38-ae12-4229-b6cb-54f0d2583628___JR_HL 8797.JPG',
#   'Pepper,_bell',
#   'Pepper,_bell___healthy'),
#  ('plantVillage_Pepper,_bell___healthy_ca67e39d-cf11-4660-b629-6654c815ce70___JR_HL 8782.JPG',
#   'Pepper,_bell',
#   'Pepper,_bell___healthy'),
#  ('plantVillage_Potato___Early_blight_bc8a7fa5-1f77-4829-a1ee-0ccbeef289eb___RS_Early.B 7228.JPG',
#   'Potato',
#   'Potato___Early_blight'),
#  ('plantVillage_Potato___Early_blight_c28107c6-ea57-4044-bb6e-508d6d360cd7___RS_Early.B 7057.JPG',
#   'Potato',
#   'Potato___Early_blight'),
#  ('plantVillage_Potato___healthy_5e19b1f4-fd65-4c4d-bcd2-18c8c519eddb___RS_HL 1965.JPG',
#   'Potato',
#   'Potato___healthy'),
#  ('plantVillage_Potato___healthy_c6204cb3-cd9f-4d7b-92a6-9773fe562cab___RS_HL 1939.JPG',
#   'Potato',
#   'Potato___healthy'),
#  ('plantVillage_Potato___Late_blight_85d29f87-cb27-4ffa-9ad8-9c47f9a53b33___RS_LB 4437.JPG',
#   'Potato',
#   'Potato___Late_blight'),
#  ('plantVillage_Potato___Late_blight_b9ad8d86-aadb-44b4-9bba-d6adb446afd7___RS_LB 5188.JPG',
#   'Potato',
#   'Potato___Late_blight'),
#  ('plantVillage_Raspberry___healthy_24b7a9e2-8a0f-42b6-9506-45fb261857fe___Mary_HL 9341.JPG',
#   'Raspberry',
#   'Raspberry___healthy'),
#  ('plantVillage_Raspberry___healthy_69de5784-3876-4928-80b9-43245d16d54d___Mary_HL 6341.JPG',
#   'Raspberry',
#   'Raspberry___healthy'),
#  ('plantVillage_Soybean___healthy_2330ac00-dfdc-4436-bbfd-0da49c4188a0___RS_HL 5896.JPG',
#   'Soybean',
#   'Soybean___healthy'),
#  ('plantVillage_Soybean___healthy_94667f5e-1d79-4406-b41a-b64d3cfb0ff8___RS_HL 5586 1.JPG',
#   'Soybean',
#   'Soybean___healthy'),
#  ('plantVillage_Squash___Powdery_mildew_527b8469-9b8e-4bdb-bd8a-24c41adec028___MD_Powd.M 0782.JPG',
#   'Squash',
#   'Squash___Powdery_mildew'),
#  ('plantVillage_Squash___Powdery_mildew_6144bf6a-4ffd-4cb7-8dea-8ccb73024937___UMD_Powd.M 9905.JPG',
#   'Squash',
#   'Squash___Powdery_mildew'),
#  ('plantVillage_Strawberry___healthy_30c218c0-6fb6-45d8-a645-43be89932d06___RS_HL 2005.JPG',
#   'Strawberry',
#   'Strawberry___healthy'),
#  ('plantVillage_Strawberry___healthy_974f90d8-f19f-4174-8cfc-a1f658e322a5___RS_HL 4669.JPG',
#   'Strawberry',
#   'Strawberry___healthy'),
#  ('plantVillage_Strawberry___Leaf_scorch_08a36568-798d-4e2e-a1a9-6341bee5d0e3___RS_L.Scorch 1494.JPG',
#   'Strawberry',
#   'Strawberry___Leaf_scorch'),
#  ('plantVillage_Strawberry___Leaf_scorch_73b8b390-0ae1-4510-b30b-e25248660f2f___RS_L.Scorch 0979.JPG',
#   'Strawberry',
#   'Strawberry___Leaf_scorch'),
#  ('plantVillage_Tomato___Bacterial_spot_49c04c82-89d6-480e-96a3-d74a14b717b3___GCREC_Bact.Sp 3274.JPG',
#   'Tomato',
#   'Tomato___Bacterial_spot'),
#  ('plantVillage_Tomato___Bacterial_spot_d449e255-119a-44cb-844a-f187518e0fc2___GCREC_Bact.Sp 5701.JPG',
#   'Tomato',
#   'Tomato___Bacterial_spot'),
#  ('plantVillage_Tomato___Early_blight_4deeae7f-b339-4d5b-969c-b69ea27c1636___RS_Erly.B 7736.JPG',
#   'Tomato',
#   'Tomato___Early_blight'),
#  ('plantVillage_Tomato___Early_blight_bac9d43f-fc43-4b89-bc2a-b8ba4a040059___RS_Erly.B 7724.JPG',
#   'Tomato',
#   'Tomato___Early_blight'),
#  ('plantVillage_Tomato___healthy_18fa622c-8257-479a-9c81-7a6fe9a3a41b___GH_HL Leaf 428.JPG',
#   'Tomato',
#   'Tomato___Late_blight'),
#  ('plantVillage_Tomato___healthy_d676d2f7-13a7-4d79-91fc-757b5d0bde6f___RS_HL 0601.JPG',
#   'Tomato',
#   'Tomato___healthy'),
#  ('plantVillage_Tomato___Late_blight_01c391d2-1b3a-4b58-b205-a75674bba6e9___GHLB2 Leaf 8824.JPG',
#   'Tomato',
#   'Tomato___Late_blight'),
#  ('plantVillage_Tomato___Late_blight_a7049041-4ef3-4c55-b4bf-7721ca5630f4___RS_Late.B 5142.JPG',
#   'Tomato',
#   'Tomato___Late_blight'),
#  ('plantVillage_Tomato___Leaf_Mold_0c0debed-e807-4236-a2e3-d9b72f54367f___Crnl_L.Mold 6899.JPG',
#   'Tomato',
#   'Tomato___Leaf_Mold'),
#  ('plantVillage_Tomato___Leaf_Mold_9dd60be7-b16d-493d-acdf-f5b7446754c7___Crnl_L.Mold 8782.JPG',
#   'Tomato',
#   'Tomato___Leaf_Mold'),
#  ('plantVillage_Tomato___Septoria_leaf_spot_694af91d-fa2c-4bdd-a1b4-0ebacc3a2cca___Matt.S_CG 1588.JPG',
#   'Tomato',
#   'Tomato___Early_blight'),
#  ('plantVillage_Tomato___Septoria_leaf_spot_6bda66a5-562c-4ad9-9e14-7d76dcbd4eef___Keller.St_CG 1880.JPG',
#   'Tomato',
#   'Tomato___Septoria_leaf_spot'),
#  ('plantVillage_Tomato___Spider_mites Two-spotted_spider_mite_83d3d054-0ca6-41bd-9b65-ae5d27f9605d___Com.G_SpM_FL 1384.JPG',
#   'Tomato',
#   'Tomato___Spider_mites Two-spotted_spider_mite'),
#  ('plantVillage_Tomato___Spider_mites Two-spotted_spider_mite_88ce9b84-50b8-4ffa-8628-1d5fe9e9a94e___Com.G_SpM_FL 1547.JPG',
#   'Tomato',
#   'Tomato___Spider_mites Two-spotted_spider_mite'),
#  ('plantVillage_Tomato___Target_Spot_4a24322a-bd1c-493c-9da4-536b89eeaf2e___Com.G_TgS_FL 8000.JPG',
#   'Tomato',
#   'Tomato___Target_Spot'),
#  ('plantVillage_Tomato___Target_Spot_a22c1ee8-6ad5-44e3-adb4-2e0223b3fa2b___Com.G_TgS_FL 0981.JPG',
#   'Tomato',
#   'Tomato___Target_Spot'),
#  ('plantVillage_Tomato___Tomato_mosaic_virus_22a98961-90fb-4ff5-a6db-6313fa61f74b___PSU_CG 2125.JPG',
#   'Tomato',
#   'Tomato___Tomato_mosaic_virus'),
#  ('plantVillage_Tomato___Tomato_mosaic_virus_fb199918-5c7f-4285-993b-3ed212140456___PSU_CG 2124.JPG',
#   'Tomato',
#   'Tomato___Tomato_mosaic_virus'),
#  ('plantVillage_Tomato___Tomato_Yellow_Leaf_Curl_Virus_a408024e-b016-4351-b4ea-54ee065eec85___UF.GRC_YLCV_Lab 03039.JPG',
#   'Tomato',
#   'Tomato___Tomato_Yellow_Leaf_Curl_Virus'),
#  ('plantVillage_Tomato___Tomato_Yellow_Leaf_Curl_Virus_d744882b-02ac-4904-8e96-4920b39ad5ce___YLCV_GCREC 5246.JPG',
#   'Tomato',
#   'Tomato___Tomato_Yellow_Leaf_Curl_Virus'),
#  ('riceleaf_bacterial_leaf_blight_bacterial_leaf_blight (118).JPG',
#   'Rice',
#   'bacterial_leaf_blight'),
#  ('riceleaf_bacterial_leaf_blight_bacterial_leaf_blight (316).JPG',
#   'Rice',
#   'bacterial_leaf_blight'),
#  ('riceleaf_brown_spot_brown_spot (210).jpg', 'Rice', 'brown_spot'),
#  ('riceleaf_healthy_healthy (271).jpg', 'Rice', 'healthy'),
#  ('riceleaf_healthy_healthy (325).jpg', 'Rice', 'healthy')]
