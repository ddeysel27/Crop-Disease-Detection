# %% [markdown]
# # 00 — Explore Datasets

# %%
from pathlib import Path
from PIL import Image
from collections import Counter
import matplotlib.pyplot as plt

raw = Path('data/raw')
print('Datasets available:', [d.name for d in raw.iterdir() if d.is_dir()])
