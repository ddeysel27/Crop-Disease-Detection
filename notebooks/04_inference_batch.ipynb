# %% [markdown]
# # 04 — Inference on a Folder

# %%
from src.models.infer import load_model, predict_topk
from PIL import Image
import json, os

model, idx2label = load_model('experiments/runs/best_model.pth','experiments/runs/label_mapping.json')
img = Image.open('assets/architecture.png').convert('RGB')  # placeholder
print(predict_topk(model, img, idx2label))
